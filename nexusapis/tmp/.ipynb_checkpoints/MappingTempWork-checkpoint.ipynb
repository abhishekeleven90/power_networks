# %%
def crawlerMappings(crawlFile):
    
    crawlFile = open(crawlFile)

    ## format of file:
    ## metainfo key value pairs
    ## ens
    ## rels etc. in order

    ens = []
    rels = []
    metainfo = {}
    currdict = {}
    curr_ch = '-'

    for line in crawlFile.readlines():
        line = line.strip()
        if line[0]=='#':

            ##adjusting the old one
            if curr_ch=='e':
                ens.append(currdict)
            elif curr_ch == 'r':
                rels.append(currdict)

            ##adjusting for the new one
            if line[1]=='e':
                ##an entity is what we are reading
                currdict = {}
                curr_ch='e'
            else:
                currdict = {}
                curr_ch='r'
                ##a relation is what we are reading
        elif curr_ch!='-':
            prop = line[0:line.find(':')].strip()
            value = line[line.find(':')+1:].strip()
            if(prop!='number' and prop!='from' and prop!='to'):
                #split
                value = value.split(',')
                #strip
                value = map(str.strip, value)
            currdict[prop] = value
        else:
            prop = line[0:line.find(':')].strip()
            value = line[line.find(':')+1:].strip()
            metainfo[prop] = value
    if curr_ch=='e':
        ens.append(currdict)
    elif curr_ch=='r':
        rels.append(currdict)
    
    return metainfo,ens,rels
crawlerMappings('crawlerMap2')
# Out:
# ({'tablename': 'political_crawl_jan'},
#  [{'graph': ['name', 'email', 'contact', 'address', 'mynetaid'],
#    'label': ['politician', 'person'],
#    'mysql': ['name', 'email', 'contact', 'address', 'mynetaid'],
#    'number': '1',
#    'resolve': ['name']}],
#  [])

# %%
import MySQLdb as db
import pandas as pd
def sqlQuerytoDF(query,ipaddress,database,user,password):
    database = db.connect(ipaddress, user, password, database)
    df = pd.read_sql(query, database)
    return df
#df = sqlQuerytoDF("select * from political_crawl_jan " + +" where resolved = 0 order by id limit 1;", "localhost","crawldb","root","yoyo")
#df['name'][0]

# %%
from py2neo import Graph, Node, Relationship

## en is the node and df is the dataframe pandas from mysql
def createNodeFromMapping(en,df):
    node =  Node()
    for label in en['label']:
        node.labels.add(label)
    for i in range(len(en['graph'])):
        node.properties[en['graph'][i]] = df[en['mysql'][i]][0]
    return node, en['resolve']

def createRelFromMapping(rel,startNode,endNode,df):
    link =  Relationship(startNode,rel['label'],endNode)
    for i in range(len(rel['graph'])):
        link.properties[rel['graph'][i]] = df[rel['mysql'][i]][0]
    return link, link['resolve']

# %%
##some temp work


meta,ens,rels = crawlerMappings('crawl_map_pol_crawl_jan')
## meta is the dict of all the meta info on the table
## ens is the list of entities
## rels is the list of relations

df = sqlQuerytoDF("select * from political_crawl_jan where resolved = 0 order by id limit 1;", "localhost","crawldb","root","yoyo")
print len(df)
## get the first row for unresloved nodes

mapNodes = {}
mapRels = {}

for en in ens:
    node = createNodeFromMapping(en,df)
    mapNodes[en['number']] = node
    print node

for rel in rels:
    startNode = mapNodes[rel['from']]
    endNode = mapNodes[rel['to']]
    link = createRelFromMapping(rel,startNode,endNode,df)
    mapRels[rel['number']] =link
    
print mapNodes  ## map of nodes from number to the exacxt node
print mapRels
print mapNodes.keys()
# Out:
# 1
# 1
# (:person:politician {address:"Andhra etc",contact:"55467878",email:"something@someone.com",mynetaid:"23",name:"Naveen Jindal"})
# {'1': <Node labels=set(['person', 'politician']) properties={'mynetaid': u'23', 'contact': u'55467878', 'name': u'Naveen Jindal', 'address': u'Andhra etc', 'email': u'something@someone.com'}>}
# {}
# ['1']

# %%
##for just one row
def mapSqlToGraph(filename):
    meta,ens,rels = crawlerMappings(filename)
    df = sqlQuerytoDF("select * from "+ meta['tablename']+" where resolved = 0 order by id limit 1;", "localhost","crawldb","root","yoyo")

    if len(df) == 0:
        return None, None

    mapNodes = {}
    mapRels = {}
    resolveNodesOn = {}
    resolveRelsOn = {}

    for en in ens:
        node, resolveOn = createNodeFromMapping(en,df)
        mapNodes[en['number']] = str(node)
        resolveNodesOn[en['number']] = resolveOn
        
    for rel in rels:
        startNode = mapNodes[rel['from']]
        endNode = mapNodes[rel['to']]
        link, resolveOn = createRelFromMapping(rel,startNode,endNode,df)
        mapRels[rel['number']] = str(link)
        resolveRelsOn[rel['number']] = resolveOn
    
    return mapNodes, mapRels, resolveNodesOn, resolveRelsOn

##Usage:
##mapSqlToGraph('crawlerMap2')


##resolver code
##used by resolve()
def getMatchingUuids(node):
    return [25, 26, 27, 28]

##used by core()
def resolveNode(node):
    
    
    ## get matching uuids
    ##    if the matching uuids is none then create the node and return the new uuid
    ##    else display the node to the user
    ##         if the user selects some uuid then proceed to diff part, and return the uuid after modifications
    ##         else user selects no match (which should be an option btw in ui) then create the node and return the new uuid
    
    
    matchingUuids = getMatchingUuids(node)
    print 'going to match against '+str(matchingUuids)
    if len(matchingUuids)==0:
        
        ##here node is the text so we need to deserialize the text to get the neo4j node
        ##generate a uuid
        ##and insert in graph database
        return wrapCreateNode(graph,node)
        
        ##and set resolved to one in crawldb correspoding to this row! ##save the id in beginnging!
        ##not to be done here ## when all nodes and rels in a subgraph get mnatched then wwe do this!
        
    else:
        ##this means how the ui
        ##and get the corresponding uuid
        ##let's say uuid 26 is returned
        
        ##imagine a fucntion call here!
        match_uuid = 26 ##what if None is there?
        
        if match_uuid is None:
            return wrapCreateNode(graph,node) ##this is the case when from all possible options none is selected!
        
        ##we will have to show the diff now with current node and node 26
        ##show the diff
        ##get updated info in flask
        ##and update the matched node push! basically!
        return match_uuid
    
    
def resolveRel():
    return 1


##adding code here that will be used
def core():
    mapNodes, mapRels, resolveNodesOn, resolveRelsOn = mapSqlToGraph('crawlerMap2')
    
    for nodeKey in mapNodes:
        node = mapNodes[nodeKey]
        print nodeKey
        print node
        node_uuid = resolveNode(node)
        print 'nodeKey: '+ nodeKey + ' resolved with uuid '+str(node_uuid)
        
    for relKey in mapRels:
        rel = mapRels[relKey]
        print relKey
        print rel
        relid = resolveRel(rel)
        print 'relKey: '+ relKey + ' resolved with relid '+str(relid)
        
##Usage:
core()
# Out:
# 1
# (:person:politician {address:"Andhra etc",contact:"55467878",email:"something@someone.com",mynetaid:"23",name:"Naveen Jindal"})
# going to match against [25, 26, 27, 28]
# nodeKey: 1 resolved with uuid 26

# %%
## nodes with almost same things just to test our work
from py2neo import Graph, Node, Relationship

username = 'neo4j'
password = 'yoyo'
server = 'localhost'
port = '7474'
con_url = 'http://'+username+':'+password+'@'+server+':'+port+'/db/data/'

graph = Graph(con_url)


def deserializeNode(nodeText):
    pos =  nodeText.find(' ')
    
    #get the labels in a set
    startText = nodeText[1:pos]
    allLabels = startText.split(':')[1:]
    allLabels =  set(allLabels) #set is imp
    
    #get the props in a dict
    endText = nodeText[pos+1:-1]
    endTextWB = endText[1:-1]
    #print endText
    #print endTextWB
    propList = endTextWB.split(",")
    propsDict = {}
    for x in propList:
        propval = x.split(":")
        #for handling the single inverted comma problem
        prop = propval[0]
        val = propval[1]
        if val[0]=="'" and val[-1]=="'":
            val=val[1:-1]
        #for handling the double inverted comma problem
        if val[0]=='"' and val[-1]=='"':
            val=val[1:-1]
        propsDict[prop]=val

    
    #print propsDict
    
    #creating the node from parsedText
    node = Node()
    for x in allLabels:
        node.labels.add(x)
    for x in propsDict:
        node[x] = propsDict[x]
    print node
    return node
node = deserializeNode(nodetxt)
#graph.create(node)
# Out:
# (:businessperson:person {` age`:"44",` email`:"sommeing@naveen.com",address:"uttar pradesh",mynetaid:"23",name:"Mr. Naveen"})

# %%
import MySQLdb as db
def createUuid(name):
    mydb = db.connect("localhost","root", 
        "yoyo","flasktemp")
    cursor = mydb.cursor()

    ##TODO: get uuidtable in constant config file 
    cursor.execute("insert into uuidtable(name) values('"+name+"')")
    mydb.commit()

    mydb.close()

    return cursor.lastrowid

# %%
def wrapCreateNode(graph, node):
    ## use this table
    ## this table inside flasktemp for now
    ## create table uuidtable(uuid bigint(20) not null auto_increment primary key, name varchar(255));
    uuid = createUuid(node['name'])
    node['uuid'] = uuid
    graph.create(node)
    node.pull()
    return node
nodetxt = '(:businessperson:person {address:"uttar pradesh", age:44, email:"sommeing@naveen.com",mynetaid:"23",name:"Mr. Naveen"})'
node = deserializeNode(nodetxt)
wrapCreateNode(graph,node)
# Out:
# (:businessperson:person {` age`:"44",` email`:"sommeing@naveen.com",address:"uttar pradesh",mynetaid:"23",name:"Mr. Naveen"})
# <Node graph=u'http://localhost:7474/db/data/' ref=u'node/12' labels=set([u'person', u'businessperson']) properties={u'name': u'Mr. Naveen', u' age': u'44', u'address': u'uttar pradesh', u'mynetaid': u'23', u' email': u'sommeing@naveen.com', u'uuid': 30}>

# %%
##helper functions section just copying

##################GRAPH DB##########################
from py2neo import Graph, Node, Relationship
import diff_match_patch
import pandas as pd

username = 'neo4j'
password = 'yoyo'
server = 'localhost'
port = '7474'
con_url = 'http://'+username+':'+password+'@'+server+':'+port+'/db/data/'

graph = Graph(con_url)

def labelsToBeAdded(orig, naya):
    new_labels = []
    for x in naya.labels:
        if x not in orig.labels:
            new_labels.append(x)
    return new_labels

def propsDiff(orig,naya):
    conf_props = []
    new_props = []
    for x in naya.properties:
        if x not in orig.properties:
            new_props.append(x)
        else:
            conf_props.append(x)
    return conf_props, new_props
##################GRAPH DB##########################
