# %% [markdown]
# # Scraping ADR's Myneta.info
#
# [Myneta.info](http://myneta.info) has analysed candidate affidavits for many candidates. This scraper converts that data into CSVs. (Of course, we could always ask ADR, and they'll probably happily provide it. But I find it faster to write a scraper than wait for people to arrive at office.)
#
# The pages are very structured. We'll begin with the [candidate summary page](http://myneta.info/ls2014/index.php?action=summary&subAction=candidates_analyzed&sort=candidate#summary).

# %%
import os
import time
import urllib
import hashlib
import pandas as pd
from lxml.html import parse

if not os.path.exists('.cache'):
    os.makedirs('.cache')
    
# If file is older than 5 days, download it again
OLD = time.time() - 15 * 24 * 60 * 60

yearkey = {
    2014: 'ls2014',
    2009: 'ls2009',
    2004: 'loksabha2004',
}

def get(url):
    path = os.path.join('.cache', hashlib.sha1(url).hexdigest()) + '.html'
    if not os.path.exists(path) or os.stat(path).st_mtime < OLD:
        print url
        urllib.urlretrieve(url, path)
    return parse(open(path))

def candidates(year):
    url = 'http://myneta.info/{:s}/index.php?action=summary&subAction=candidates_analyzed&sort=candidate'
    tree = get(url.format(yearkey[year]))
    results = []
    for row in tree.findall('.//table')[-1].findall('tr'):
        td = row.findall('td')
        results.append({
            'Year': year,
            'Sno': td[0].text,
            'ID': int(td[1].find('a').get('href').split('=')[-1]),
            'Candidate': td[1].find('a').text,
            'Constituency': td[2].text,
            'Party': td[3].text,
            'Criminal Cases': int(td[4].text_content()),
            'Education': td[5].text,
            'Total Assets': int(td[6].text.replace(u'Rs\xa0', '').replace(',', '').replace('Nil', '0')),
            'Total Liabilities': int(td[7].text.replace(u'Rs\xa0', '').replace(',', '').replace('Nil', '0')),
        })
    return pd.DataFrame(results)

# %%
ls2014 = candidates(2014)
ls2014
# Out:
#                                               Candidate  \
# 0                                         Kaushal Yadav
# 1                                      M. Aamir Rashadi
# 2                                     Rakesh Kumar Giri
# 3                                    (Kuppal)G.Devadoss
# 4     (Maj Gen (Retd.) ) Bhuwan Chandra Khanduri (Avsm)
# 5                                                A Biju
# 6                                     A N Radhakrishnan
# 7                                              A Nelson
# 8                                   A P Jithender Reddy
# 9                                             A Pandian
# 10                                             A Prasad
# 11                                            A Sampath
# 12                                          A Thavamani
# 13                                     A Vijayaraghavan
# 14                                           A. Devadas
# 15                                       A. Irudayadass
# 16                                         A. Jaiganesh
# 17                                         A. Josekutty
# 18                                            A. Magesh
# 19                                       A. P. Shamseer
# 20                                   A. Raghunath Varma
# 21                                   A. Shadhick Batcha
# 22                                    A.Arunmozhithevan
# 23                                             A.Baskar
# 24                                            A.Ganesan
# 25                                        A.Govindasamy
# 26                                    A.Hamid Sh. Habib
# 27                                        A.K. Aggarwal
# 28                                        A.K. Aggarwal
# 29                                           A.K. Mohan
# ...                                                 ...
# 8175                                             Yogesh
# 8176                               Yogesh Chandra Bhatt
# 8177                                       Yogesh Kumar
# 8178                                       Yogesh Kumar
# 8179                             Yogesh Kumar Singh Ad.
# 8180                             Yogesh Motiram Kathore
# 8188                        DMDK  8189      79725701           30105940  2014
# 8189                         IND  8190        975000                  0  2014
# 8190                          SP  8191     331958000            2362000  2014
# 8191                         INC  8192       4699334                  0  2014
# 8192                         IND  8193        287800                  0  2014
# 8193                     SUCI(C)  8194        587593                  0  2014
# 8194                         AAP  8195      11350000                  0  2014
# 8195                         BSP  8196       1309472              45000  2014
# 8196                        INLD  8197      81039887             789903  2014
# 8197                          SP  8198        232000                  0  2014
# 8198                       AIUDF  8199       8696996           14900000  2014
# 8199                         IND  8200       1140019                  0  2014
# 8200                        AITC  8201        390500                  0  2014
# 8201         Bahujan Mukti Party  8202       1698000             800000  2014
# 8202                         IND  8203       3182000              85168  2014
# 8203                     SUCI(C)  8204         34000                  0  2014
# 8204                        SDPI  8205        557800                  0  2014
#
# [8205 rows x 10 columns]

# %%
ls2014[ls2014.ID==4041]
ls2014.to_csv('myneta.2014.csv', index=False)

# %%
ls2014 = candidates(2014)

# The constituency page does not provide the state and PC code
# So let's introduce that, at least for 2014.
pc2014 = pd.read_csv('pc2014.csv').set_index('Constituency')
ls2014['ST_CODE'] = ls2014['Constituency'].apply(lambda v: pc2014['ST_CODE'].get(v, ''))
ls2014['PC_CODE'] = ls2014['Constituency'].apply(lambda v: pc2014['PC_CODE'].get(v, ''))

# However, some corrections are required for duplicate constituencies
index = ls2014[(ls2014['Constituency'] == 'AURANGABAD') & (ls2014['ID'] > 5000)].index
ls2014['ST_CODE'][index] = 'S13'
ls2014['PC_CODE'][index] = 19

index = ls2014[(ls2014['Constituency'] == 'MAHARAJGANJ') & (ls2014['ID'] > 9000)].index
ls2014['ST_CODE'][index] = 'S24'
ls2014['PC_CODE'][index] = 63

index = ls2014[(ls2014['Constituency'] == 'HAMIRPUR') & (ls2014['ID'] < 7000)].index
ls2014['ST_CODE'][index] = 'S24'
ls2014['PC_CODE'][index] = 47

# Save to disk
ls2014.to_csv('myneta.2014.csv', index=False)
ls2014.head()
# Out:
# http://myneta.info/ls2014/index.php?action=summary&subAction=candidates_analyzed&sort=candidate
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-b011150a8745> in <module>()
#       3 # The constituency page does not provide the state and PC code
#       4 # So let's introduce that, at least for 2014.
# ----> 5 pc2014 = pd.read_csv('pc2014.csv').set_index('Constituency')
#       6 ls2014['ST_CODE'] = ls2014['Constituency'].apply(lambda v: pc2014['ST_CODE'].get(v, ''))
#       7 ls2014['PC_CODE'] = ls2014['Constituency'].apply(lambda v: pc2014['PC_CODE'].get(v, ''))
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3143)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5765)()
#
# IOError: File pc2014.csv does not exist

# %%
ls2009 = candidates(2009)
ls2009.to_csv('myneta.2009.csv', index=False)

ls2004 = candidates(2004)
ls2004.to_csv('myneta.2004.csv', index=False)

# %% [markdown]
# # Candidate details
#
# Let's scraping the IPC sections and asset breakup.
#
# (As I supsected, writing the scraper took less time (40 min) than I think it'd have taken to get the information even from an organisation as friendly as ADR.)

# %%
import re

re_ipcs = re.compile(r'(\d+) charges related to .*?IPC Section\-(\d+)')

def candidate(year, id):
    url = 'http://myneta.info/{:s}/candidate.php?candidate_id={:d}'.format(yearkey[year], id)
        
    tree = get(url)
    result = []
    ipcs = tree.xpath(".//h3[contains(text(), 'Brief Details of IPCs')]")
    if len(ipcs):
        ipcs = ipcs[0].getparent().text_content()
        for count, ipc_section in re_ipcs.findall(ipcs):
            result.append({
                'Type': 'IPC',
                'Year': year,
                'ID': id,
                'Key': ipc_section,
                'Value': int(count)
            })

    for heading in tree.xpath(".//h3[contains(text(), 'ovable Assets')]"):
        # Ignore 1st header row, last total rows from table
        for row in heading.getparent().getnext().findall('.//tr')[1:-1]:
            cells = row.findall('.//td')
            # Since rowspan is used for some cells, description is in 1st / 2nd col
            key = cells[0].text_content()
            if key[0].islower():
                key = cells[1].text_content()
            if 'Total' in key:
                key = 'Total as per Affidavit'
            result.append({
                'Type': 'Assets',
                'Year': year,
                'ID': id,
                'Key': key,
                'Value': int(re.sub(r'\D', '', cells[-1].find('.//b').text) or 0)
            })
            
    return pd.DataFrame(result)

# %%
ls2014_details = []
for index, row in ls2014.iterrows():
    ls2014_details.append(candidate(2014, row['ID']))

ls2014_details = pd.concat(ls2014_details)
# Out:
# http://myneta.info/ls2014/candidate.php?candidate_id=148
# http://myneta.info/ls2014/candidate.php?candidate_id=9496
# http://myneta.info/ls2014/candidate.php?candidate_id=9706
# http://myneta.info/ls2014/candidate.php?candidate_id=6912
# http://myneta.info/ls2014/candidate.php?candidate_id=74
# http://myneta.info/ls2014/candidate.php?candidate_id=1906
# http://myneta.info/ls2014/candidate.php?candidate_id=8
# http://myneta.info/ls2014/candidate.php?candidate_id=4337
# http://myneta.info/ls2014/candidate.php?candidate_id=4536
# http://myneta.info/ls2014/candidate.php?candidate_id=901
# http://myneta.info/ls2014/candidate.php?candidate_id=1105
# http://myneta.info/ls2014/candidate.php?candidate_id=340
# http://myneta.info/ls2014/candidate.php?candidate_id=7501
# http://myneta.info/ls2014/candidate.php?candidate_id=173
# http://myneta.info/ls2014/candidate.php?candidate_id=397
# http://myneta.info/ls2014/candidate.php?candidate_id=6929
# http://myneta.info/ls2014/candidate.php?candidate_id=6913
# http://myneta.info/ls2014/candidate.php?candidate_id=336
# http://myneta.info/ls2014/candidate.php?candidate_id=6943
# http://myneta.info/ls2014/candidate.php?candidate_id=1850
# http://myneta.info/ls2014/candidate.php?candidate_id=117
# http://myneta.info/ls2014/candidate.php?candidate_id=4341
# http://myneta.info/ls2014/candidate.php?candidate_id=3955
# http://myneta.info/ls2014/candidate.php?candidate_id=4048
# http://myneta.info/ls2014/candidate.php?candidate_id=6284
# http://myneta.info/ls2014/candidate.php?candidate_id=6356
# http://myneta.info/ls2014/candidate.php?candidate_id=5202
# http://myneta.info/ls2014/candidate.php?candidate_id=9741
# http://myneta.info/ls2014/candidate.php?candidate_id=993
# http://myneta.info/ls2014/candidate.php?candidate_id=5381
# http://myneta.info/ls2014/candidate.php?candidate_id=6292
# http://myneta.info/ls2014/candidate.php?candidate_id=2206
# http://myneta.info/ls2014/candidate.php?candidate_id=6357
# http://myneta.info/ls2014/candidate.php?candidate_id=700
# http://myneta.info/ls2014/candidate.php?candidate_id=4041
# http://myneta.info/ls2014/candidate.php?candidate_id=7496
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f2860da28598> in <module>()
#       1 ls2014_details = []
#       2 for index, row in ls2014.iterrows():
# ----> 3     ls2014_details.append(candidate(2014, row['ID']))
#       4
#       5 ls2014_details = pd.concat(ls2014_details)
#
# <ipython-input-6-02cd1d4e1dc8> in candidate(year, id)
#       6     url = 'http://myneta.info/{:s}/candidate.php?candidate_id={:d}'.format(yearkey[year], id)
#       7
# ----> 8     tree = get(url)
#       9     result = []
#      10     ipcs = tree.xpath(".//h3[contains(text(), 'Brief Details of IPCs')]")
#
# <ipython-input-3-77538c664512> in get(url)
#      22     if not os.path.exists(path) or os.stat(path).st_mtime < OLD:
#      23         print url
# ---> 24         urllib.urlretrieve(url, path)
#      25     return parse(open(path))
#      26
#
# /usr/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data)
#      92     if not _urlopener:
#      93         _urlopener = FancyURLopener()
# ---> 94     return _urlopener.retrieve(url, filename, reporthook, data)
#      95 def urlcleanup():
#      96     if _urlopener:
#
# /usr/lib/python2.7/urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     238             except IOError:
#     239                 pass
# --> 240         fp = self.open(url, data)
#     241         try:
#     242             headers = fp.info()
#
# /usr/lib/python2.7/urllib.pyc in open(self, fullurl, data)
#     206         try:
#     207             if data is None:
# --> 208                 return getattr(self, name)(url)
#     209             else:
#     210                 return getattr(self, name)(url, data)
#
# /usr/lib/python2.7/urllib.pyc in open_http(self, url, data)
#     344         for args in self.addheaders: h.putheader(*args)
#     345         h.endheaders(data)
# --> 346         errcode, errmsg, headers = h.getreply()
#     347         fp = h.getfile()
#     348         if errcode == -1:
#
# /usr/lib/python2.7/httplib.pyc in getreply(self, buffering)
#    1115         try:
#    1116             if not buffering:
# -> 1117                 response = self._conn.getresponse()
#    1118             else:
#    1119                 #only add this keyword if non-default for compatibility
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1043         response = self.response_class(*args, **kwds)
#    1044
# -> 1045         response.begin()
#    1046         assert response.will_close != _UNKNOWN
#    1047         self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     407         # read until we get a non-100 response
#     408         while True:
# --> 409             version, status, reason = self._read_status()
#     410             if status != CONTINUE:
#     411                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     363     def _read_status(self):
#     364         # Initialize with Simple-Response defaults
# --> 365         line = self.fp.readline(_MAXLINE + 1)
#     366         if len(line) > _MAXLINE:
#     367             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
ls2014_details
# Out:
#       ID                                                Key    Type    Value  \
# 0    148                                                420     IPC        3
# 1    148                                                467     IPC        2
# 2    148                                                468     IPC        2
# 3    148                                                307     IPC        1
# 4    148                                                379     IPC        1
# 5    148                                                411     IPC        1
# 6    148                                                131     IPC        1
# 7    148                                                133     IPC        1
# 8    148                                                120     IPC        4
# 9    148                                                188     IPC        3
# 10   148                                                341     IPC        2
# 11   148                                                342     IPC        2
# 12   148                                                471     IPC        2
# 13   148                                                147     IPC        1
# 14   148                                                148     IPC        1
# 15   148                                                149     IPC        1
# 16   148                                                323     IPC        1
# 17   148                                                427     IPC        1
# 18   148                                                337     IPC        1
# 19   148                                                353     IPC        1
# 20   148                                                504     IPC        1
# 21   148                                                114     IPC        1
# 22   148                                                116     IPC        1
# 23   148                                               Cash  Assets  4800000
# 24   148  Deposits in Banks, Financial Institutions and ...  Assets   786134
# 25   148          Bonds, Debentures and Shares in companies  Assets   500000
# 26   148                        (a) NSS, Postal Savings etc  Assets        0
# 27   148                (b)LIC or other insurance Policies   Assets  4575000
# 28   148                      Personal loans/advance given   Assets        0
# 29   148             Motor Vehicles (details of make, etc.)  Assets  1500000
# ..   ...                                                ...     ...      ...
# 7    700          Bonds, Debentures and Shares in companies  Assets        0
# 8    700                        (a) NSS, Postal Savings etc  Assets        0
# 9    700                (b)LIC or other insurance Policies   Assets        0
# 10   700                      Personal loans/advance given   Assets        0
# 11   700             Motor Vehicles (details of make, etc.)  Assets    40000
# 12   700              Jewellery (give details weight value)  Assets   500000
# 13   700  Other assets, such as values of claims / inter...  Assets        0
# 14   700                             Total as per Affidavit  Assets   562365
# 15   700                                  Agricultural Land  Assets        0
# 16   700                              Non Agricultural Land  Assets  6000000
# 17   700                               Commercial Buildings  Assets        0
# 18   700                              Residential Buildings  Assets  5877800
# 19   700                                             Others  Assets        0
# 20   700                             Total as per Affidavit  Assets  6000000
# 0   4041                                               Cash  Assets        0
# 1   4041  Deposits in Banks, Financial Institutions and ...  Assets        0
# 2   4041          Bonds, Debentures and Shares in companies  Assets        0
# 3   4041                        (a) NSS, Postal Savings etc  Assets        0
# 4   4041                (b)LIC or other insurance Policies   Assets        0
# 5   4041                      Personal loans/advance given   Assets        0
# 6   4041             Motor Vehicles (details of make, etc.)  Assets        0
# 7   4041              Jewellery (give details weight value)  Assets        0
# 8   4041  Other assets, such as values of claims / inter...  Assets        0
# 9   4041                             Total as per Affidavit  Assets        0
# 10  4041                                  Agricultural Land  Assets        0
# 11  4041                              Non Agricultural Land  Assets        0
# 12  4041                               Commercial Buildings  Assets        0
# 13  4041                              Residential Buildings  Assets        0
# 14  4041                                             Others  Assets        0
# 15  4041                             Total as per Affidavit  Assets        0
#
#     Year
# 0   2014
# 1   2014
# 2   2014
# 3   2014
# 4   2014
# 5   2014
# 6   2014
# 7   2014
# 8   2014
# 9   2014
# 10  2014
# 11  2014
# 12  2014
# 13  2014
# 14  2014
# 15  2014
# 16  2014
# 17  2014
# 18  2014
# 19  2014
# 20  2014
# 21  2014
# 22  2014
# 23  2014
# 24  2014
# 25  2014
# 26  2014
# 27  2014
# 28  2014
# 29  2014
# ..   ...
# 7   2014
# 8   2014
# 9   2014
# 10  2014
# 11  2014
# 12  2014
# 13  2014
# 14  2014
# 15  2014
# 16  2014
# 17  2014
# 18  2014
# 19  2014
# 20  2014
# 0   2014
# 1   2014
# 2   2014
# 3   2014
# 4   2014
# 5   2014
# 6   2014
# 7   2014
# 8   2014
# 9   2014
# 10  2014
# 11  2014
# 12  2014
# 13  2014
# 14  2014
# 15  2014
#
# [624 rows x 5 columns]

# %%
ls2014_details.to_csv('myneta.details.2014.csv', index=False)
ls2014_details.head()
# Out:
#     ID  Key Type  Value  Year
# 0  148  420  IPC      3  2014
# 1  148  467  IPC      2  2014
# 2  148  468  IPC      2  2014
# 3  148  307  IPC      1  2014
# 4  148  379  IPC      1  2014
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Candidates with shares
#
# Some URLS have share information. Next step is to scrape those as well.
#
# - http://myneta.info/ls2014/candidate.php?candidate_id=214
# - http://myneta.info/ls2014/candidate.php?candidate_id=74
# - http://myneta.info/ls2014/candidate.php?candidate_id=1142
# - http://myneta.info/ls2014/candidate.php?candidate_id=4988
